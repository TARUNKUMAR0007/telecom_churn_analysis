# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('python bank churn dta.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# there are some balnk values in total charges we need to replace it with 0 and convert that data type into float
df['TotalCharges'] = df['TotalCharges'].replace(' ', 0)
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'])
# here we replaced blanks with 0 beacuse as tenure is 0 and total charges are recorded

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# checking for duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['customerID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
# now we are converting senior citizen values 0 and 1 to yes or no making it easier to understand
def conversion(value):
    if value == 1:
        return 'Yes'
    else:
        return 'No'
df['SeniorCitizen'] = df['SeniorCitizen'].apply(conversion)

# %%
df
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            No     Yes         No       1
# 1     5575-GNVDE    Male            No      No         No      34
# 2     3668-QPYBK    Male            No      No         No       2
# 3     7795-CFOCW    Male            No      No         No      45
# 4     9237-HQITU  Female            No      No         No       2
# ...          ...     ...           ...     ...        ...     ...
# 7038  6840-RESVB    Male            No     Yes        Yes      24
# 7039  2234-XADUH  Female            No     Yes        Yes      72
# 7040  4801-JZAZL  Female            No     Yes        Yes      11
# 7041  8361-LTMKD    Male           Yes     Yes         No       4
# 7042  3186-AJIEK    Male            No      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# analysis
sns.countplot(x='Churn',data = df)
plt.show()
# this is not clear lets make some modifications

# %%
ax = sns.countplot(x = 'Churn',data = df)
ax.bar_label(ax.containers[0])
plt.title('count of customers by churn')
plt.show()

# %%
#in terms of percentage
gb = df.groupby('Churn').agg({'Churn': 'count'})
gb
# Out:
#        Churn
# Churn
# No      5174
# Yes     1869

# %%
gb = df.groupby('Churn').agg({'Churn' : 'count'})
plt.pie(gb['Churn'])
plt.show()
# this is not clear

# %%
plt.figure(figsize = (4,4))
gb = df.groupby('Churn').agg({'Churn' : 'count'})
plt.pie(gb['Churn'],labels = gb.index,autopct = '%1.2f%%')
plt.title('Percentage of Churned Customers')
plt.show()

# %% [markdown]
# #conclusion of the above is from the bar chart we conclude that 26.54% of our customers have churned out

# %%
# now lets explore the reason why the customers had churned out

# %%
# now lets check based on gender
plt.figure(figsize=(5,5))
sns.countplot(x='gender', data=df, hue='Churn')
plt.title('Churn by Gender')
plt.show()

# %%
# Based on senior Citizen
plt.figure(figsize=(5,5))
sns.countplot(x='SeniorCitizen', data=df, hue='Churn')
plt.title('Churn by Senior Citizen')
plt.show()

# %%
# stack plot of Senior citizens
plt.figure(figsize=(6,5))
cross_tab = pd.crosstab(df['SeniorCitizen'], df['Churn'], normalize='index') * 100  # Convert to percentages
cross_tab.plot(kind='bar', stacked=True, colormap='viridis', figsize=(6,5), edgecolor='black')

plt.title('Churn Percentage by Senior Citizen Status')
plt.xlabel('Senior Citizen (0 = No, 1 = Yes)')
plt.ylabel('Percentage (%)')
plt.legend(title='Churn')
plt.xticks(rotation=0)
plt.show()

# %%
#count of customers churned by senior citizen
ax = sns.countplot(x='SeniorCitizen',data = df)
ax.bar_label(ax.containers[0])
plt.title('count of customers churned by senior citizen')
plt.show()

# %% [raw]
# # comparitively a greater percentage of senior citizens has churned out

# %%
# Based on tenure
plt.figure(figsize = (9,4))
sns.histplot(x = 'tenure',data = df,bins = 72,hue = 'Churn')
plt.show()

# %% [raw]
# # people who have used for services for a long time have stayed and people who have used our services for a less time have churned out mostly( one or two months only).

# %%
# based on contract
plt.figure(figsize = (4,4))
ax = sns.countplot(x = 'Contract',data =df,hue = 'Churn')
ax.bar_label(ax.containers[0])
plt.title('count of customers by contract')
plt.show()

# %% [raw]
# # people who have a contract of month to month are likely to churned out than from who a contract of 1 or 2 years

# %%
# Now lets do based on services

# %%
# list of columns which we want to create  count plots
columns = ["PhoneService", "MultipleLines", "InternetService", 
           "OnlineSecurity", "OnlineBackup", "DeviceProtection", 
           "TechSupport", "StreamingTV", "StreamingMovies"]
n_cols = 3  
n_rows = (len(columns) + n_cols - 1) // n_cols  # Calculate required rows
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows * 4))
axes = axes.flatten()
for i, col in enumerate(columns):
    sns.countplot(x=col, data=df, hue="Churn", ax=axes[i])
    axes[i].set_title(f"Count Plot of {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
plt.tight_layout()
plt.show()

# %% [raw]
# # Customers with PhoneService & InternetService (DSL) are less likely to churn.
# # Churn rates are higher when OnlineBackup, TechSupport, and StreamingTV are not used or unavailable.
# # Offering more bundled services can help reduce churn.

# %%
# Based on Payment method
plt.figure(figsize = (4,4))
ax = sns.countplot(x = 'PaymentMethod',data = df,hue = 'Churn')
ax.bar_label(ax.containers[0])
plt.title('churned customers by  payment method')
plt.xticks(rotation = 65)
plt.show()
